# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
import catboost as cb
import time
from sklearn.metrics import mean_squared_error as mse
from sklearn.model_selection import StratifiedKFold, KFold
from matplotlib.pyplot import plot, show, title
import matplotlib.pyplot as plt

from lunarcalendar import Converter, Solar, Lunar

import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns',None) 
    
df_train = pd.read_csv('data/A榜-训练集_海上风电预测_气象变量及实际功率数据.csv', encoding='gbk')
# df_train = pd.read_csv('data/A榜-训练集_海上风电预测_气象变量及实际功率数据-清洗后的数据2.csv', encoding='gbk')
# df_train = pd.read_csv('data/A榜-训练集_海上风电预测_气象变量及实际功率数据-清洗后的数据3.csv', encoding='gbk')
df_test = pd.read_csv('data/A榜-测试集_海上风电预测_气象变量数据.csv', encoding='gbk')

add_df = pd.read_csv('data/A榜-训练集_海上风电预测_基本信息.csv', encoding='gbk')
# add_df = pd.read_csv('df_train/A榜-训练集_海上风电预测_基本信息.csv')
print(df_test.columns)
df = pd.concat([df_train, df_test])
df = df.merge(add_df[['站点编号', '装机容量(MW)']], on='站点编号', how='left')
df['站点编号_le'] = df['站点编号'].map(lambda x: int(x[1]))

df['time'] = pd.to_datetime(df['时间'], format='mixed')
df['day'] = df['time'].dt.day
df['weekday'] = df['time'].dt.weekday
df['hour'] = df['time'].dt.hour
df['month'] = df['time'].dt.month
df['minute'] = df['time'].dt.minute


# 定义一个函数来转换 datetime 到农历日期  
def datetime_to_lunar_month(time):  
#     lunar_date = LunarCalendar.fromSolarDate(dt.year, dt.month, dt.day)  
    lunar_date = Converter.Solar2Lunar(time)  
    return lunar_date.month

def datetime_to_lunar_day(time):  
#     lunar_date = LunarCalendar.fromSolarDate(dt.year, dt.month, dt.day)  
    lunar_date = Converter.Solar2Lunar(time)  
    return lunar_date.day

# 应用函数到 DataFrame 的 'date' 列  
# df['month_lunar'] = df['time'].apply(datetime_to_lunar_month) 
# df['day_lunar'] = df['time'].apply(datetime_to_lunar_day)

# df['站点编号'] = df['站点编号'].astype('category')
# df['hour_sin'] = np.sin(df['hour'] / 23 * 2 * np.pi)
# df['hour_cos'] = np.cos(df['hour'] / 23 * 2 * np.pi)
# df['minute_sin'] = np.sin(df['minute'] / 59 * 2 * np.pi)
# df['minute_cos'] = np.cos(df['minute'] / 59 * 2 * np.pi)
df['time_96'] = df.apply(lambda x: (x['hour'] * 60 + x['minute']) / 15 + 1, axis=1)

# df['num_samples'] = list(range(len(df)))


# for col in ['10米风速（10m/s）','100m风速（100m/s）']:
#     df[col+'_squ'] = df[col] ** 2
#     df[col+'_cub'] = df[col] ** 3
#     df[col+'_mean'] = df[col].mean()
#     df[col+'_max'] = df[col].max()
#     df[col+'_min'] = df[col].min()
#     df[col+'_std'] = df[col].std()
#     df[col+'_25'] = df[col].quantile(0.25)
#     df[col+'_50'] = df[col].median()
#     df[col+'_75'] = df[col].quantile(0.75)


df_fs100_mean = df['100m风速（100m/s）'].groupby([df['站点编号'],df['month'],df['weekday'],df['hour']]).mean()
df_fs10_mean = df['10米风速（10m/s）'].groupby([df['站点编号'],df['month'],df['weekday'],df['hour']]).mean()
merged_df = pd.merge(df, df_fs100_mean, on=['站点编号','month','weekday', 'hour'])
merged_df = pd.merge(merged_df, df_fs10_mean, on=['站点编号','month','weekday', 'hour'])

# df_fs100_mean = df['100m风速（100m/s）'].groupby([df['站点编号'],df['day'],df['hour']]).mean()
# df_fs10_mean = df['10米风速（10m/s）'].groupby([df['站点编号'],df['day'],df['hour']]).mean()
# merged_df = pd.merge(df, df_fs100_mean, on=['站点编号','day', 'hour'])
# merged_df = pd.merge(merged_df, df_fs10_mean, on=['站点编号','day', 'hour'])

# print(fs100_mean)
# print(fs10_mean)

# merged_df = merged_df.assign(m100fs_mean=merged_df['100m风速（100m/s）_y'],m10fs_mean=merged_df['10米风速（10m/s）_y'])
# merged_df = merged_df.drop(['100m风速（100m/s）_y', '10米风速（10m/s）_y'], axis=1)
merged_df.rename(columns={'100m风速（100m/s）_x':'100m风速（100m/s）', '10米风速（10m/s）_x':'10米风速（10m/s）',
                          '100m风速（100m/s）_y':'100m风速（100m/s）_mean', '10米风速（10m/s）_y':'10米风速（10m/s）_mean'}, inplace=True)


# df_fx100_mean = merged_df['100m风向（°)'].groupby([merged_df['站点编号'],merged_df['month'],merged_df['weekday']]).mean()
# df_fx10_mean = merged_df['10米风向（°)'].groupby([merged_df['站点编号'],merged_df['month'],merged_df['weekday']]).mean()
# merged_df = pd.merge(merged_df, df_fx100_mean, on=['站点编号','month','weekday'])
# merged_df = pd.merge(merged_df, df_fx10_mean, on=['站点编号','month','weekday'])

# merged_df.rename(columns={'100m风向（°)_x':'100m风向（°)', '10米风向（°)_x':'10米风向（°)',
#                           '100m风向（°)_y':'100m风向（°)_mean', '10米风向（°)_y':'10米风向（°)_mean'}, inplace=True)

merged_df = merged_df.sort_values(by=['站点编号','time'],ascending=[True, True])
df = merged_df.reset_index(drop=True)
print(df[0:5])

for col in ['10米风向（°)', '100m风向（°)']:
    df[col+"_sin"]=df[col].apply(lambda x: np.sin(x/180*np.pi))
    df[col+"_cos"]=df[col].apply(lambda x: np.cos(x/180*np.pi))
    
print(f"gap feature")
# gaps=[1,2,4,7,15,30,50,80]
gaps=[1,2,4,8,16,32,48,96,192,288]
for gap in gaps:
#     for col in ['气压(Pa）', '相对湿度（%）', '云量', '10米风速（10m/s）', '10米风向（°)', '温度（K）',
#            '辐照强度（J/m2）', '降水（m）', '100m风速（100m/s）', '100m风向（°)']:
    for col in ['气压(Pa）', '相对湿度（%）', '云量', '10米风速（10m/s）',  '温度（K）',
            '降水（m）', '100m风速（100m/s）']:
        df[col+f"_shift{gap}"]=df[col].groupby(df['站点编号']).shift(gap, fill_value=0)
        df[col+f"_gap{gap}"]=df[col+f"_shift{gap}"]-df[col]
        df.drop([col+f"_shift{gap}"],axis=1,inplace=True)


# print("one hot encoder")
# for col in ['站点编号']:
#     unique_value=df[col].unique()
#     for value in unique_value:
#         df[col+"_"+str(value)]=(df[col]==value)
#     df.drop([col],axis=1,inplace=True)


LABEL = '出力(MW)'
df.loc[df[LABEL]=='<NULL>', LABEL] = None
df.bfill(inplace=True)

# df_train = df[df[LABEL].notna()]
# df_test = df[df[LABEL].isna()].reset_index(drop=True)

df_train = df[df['time']< '2023-05-01 0:0:0']
df_test = df[df['time'] >= '2023-05-01 0:0:0']

print(len(df_train))
df_train = df_train[df_train[LABEL]!='<NULL>'].reset_index(drop=True)
df_train[LABEL] = df_train[LABEL].astype('float32')
print(len(df_train))

# 出力归一化
df_train[LABEL] = df_train[LABEL]/df_train['装机容量(MW)']

params_lgb = {
    'learning_rate': 0.03,
    'boosting_type': 'gbdt',
    'objective': 'mse',
    'metric': 'mse',
    'num_leaves': 64,
    'verbose': 1,
    'seed': 13,
    'n_jobs': -1,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.9,
    'bagging_freq': 4,
}

params_cb = {
    'learning_rate': 0.03,
    'loss_function': "RMSE",
    'eval_metric': "RMSE",
    'min_data_in_leaf': 64,
    'random_seed': 13,
    'logging_level': 'Silent',
    'use_best_model': True,
    'one_hot_max_size': 5,   #类别数量多于此数将使用ordered target statistics编码方法,默认值为2。
    'boosting_type':"Ordered", #Ordered 或者Plain,数据量较少时建议使用Ordered,训练更慢但能够缓解梯度估计偏差。
    'max_ctr_complexity': 2, #特征组合的最大特征数量，设置为1取消特征组合，设置为2只做两个特征的组合,默认为4。
    'nan_mode': 'Min' 
}

importance = 0
# MODEL_TYPE = 'lgb'

print(df_train.head())


sub_train_df = df_train[df_train['time'] < '2023-02-01 0:0:0']
sub_val_df = df_train[df_train['time'] >= '2023-02-01 0:0:0']


# feats = [f for f in sub_train_df.columns if f not in [LABEL, '时间', 'time',  '站点编号', 'min']]
# feats = [f for f in sub_train_df.columns if f not in [LABEL, '时间', 'time', '站点编号_le']]
feats = [f for f in sub_train_df.columns if f not in [LABEL, '时间', 'time',  '站点编号', 'minute']]
print(feats)

train = lgb.Dataset(sub_train_df[feats],
                    sub_train_df[LABEL])
val = lgb.Dataset(sub_val_df[feats],
                  sub_val_df[LABEL])

early_stopping = 200
model = lgb.train(params_lgb, train, valid_sets=[train, val], num_boost_round=5000, callbacks=[lgb.early_stopping(early_stopping), lgb.log_evaluation(100)])
# model_cat = cb.CatBoostRegressor(iterations=1000,  early_stopping_rounds = early_stopping, **params_cb)
# model_cat.fit(sub_train_df[feats], sub_train_df[LABEL], eval_set=(sub_val_df[feats], sub_val_df[LABEL]), verbose=True, plot=True)

val_pred = model.predict(sub_val_df[feats])
# val_pred_cat = model_cat.predict(sub_val_df[feats])

s_mse = mse(sub_val_df[LABEL]*sub_val_df['装机容量(MW)'], val_pred*sub_val_df['装机容量(MW)'], squared=False)
# s_mse_cat = mse(sub_val_df[LABEL]*sub_val_df['装机容量(MW)'], val_pred_cat*sub_val_df['装机容量(MW)'], squared=False)

# val_pred_fusion = (val_pred + val_pred_cat)/2
# s_mse_fusion = mse(sub_val_df[LABEL]*sub_val_df['装机容量(MW)'], val_pred_fusion*sub_val_df['装机容量(MW)'], squared=False)

score = 1/(1+s_mse)
print('score... %.5f'%score, 'rmse...%.5f'%s_mse)

# score_cat = 1/(1+s_mse_cat)
# print('score... %.5f'%score_cat, 'rmse...%.5f'%s_mse_cat)

# score_fusion = 1/(1+s_mse_fusion)
# print('score... %.5f'%score_fusion, 'rmse...%.5f'%s_mse_fusion)

print('feature importance of lightgbm:')
importance += model.feature_importance(importance_type='gain')
feats_importance = pd.DataFrame()
feats_importance['name'] = feats
feats_importance['importance'] = importance
print(feats_importance.sort_values('importance', ascending=False)[:30])

# print('feature importance of catboost:')
# print(model_cat.get_feature_importance(prettified=True)[:30])


plt.figure(figsize=(10,8), dpi=200)
plt.plot(sub_val_df[LABEL].values)
plt.plot(val_pred)
plt.show()

model = lgb.train(params_lgb, lgb.Dataset(df_train[feats], df_train[LABEL]), num_boost_round=model.best_iteration)
# params_cb['use_best_model'] = False
# params_cb['iterations'] = model_cat.get_best_iteration()
# model_cat = cb.CatBoostRegressor(**params_cb)
# model_cat.fit(df_train[feats], df_train[LABEL], verbose=True, plot=True)

pred_y = model.predict(df_test[feats])

# pred_y_cat = model_cat.predict(df_test[feats])
# pred_y_fusion = (pred_y+pred_y_cat)/2

df_test[LABEL] = pred_y*df_test['装机容量(MW)']
# df_test[LABEL] = pred_y_fusion*df_test['装机容量(MW)']

df_test[['站点编号','时间','出力(MW)']].to_csv('ans/lgb_base_%.5f.csv'%score, index=False)
# df_test[['站点编号','时间','出力(MW)']].to_csv('ans/lgb_base_%.5f.csv'%score_fusion, index=False)
# Out:
# Index(['站点编号', '时间', '气压(Pa）', '相对湿度（%）', '云量', '10米风速（10m/s）', '10米风向（°)',
#        '温度（K）', '辐照强度（J/m2）', '降水（m）', '100m风速（100m/s）', '100m风向（°)'],
#       dtype='object')
#   站点编号             时间       气压(Pa）  相对湿度（%）        云量  10米风速（10m/s）  10米风向（°)  \
# 0   f1  2022-1-3 0:00  102249.6094  74.8513  0.007812        7.7041   26.5195
# 1   f1  2022-1-3 0:15  102252.0355  74.7530  0.000924        7.7710   23.5766
# 2   f1  2022-1-3 0:30  102248.5900  74.4995  0.003009        7.8272   21.5451
# 3   f1  2022-1-3 0:45  102240.4725  74.1432  0.011402        7.8637   20.2394
# 4   f1  2022-1-3 1:00  102228.8828  73.7366  0.023438        7.8781   19.4870
#
#       温度（K）  辐照强度（J/m2）     降水（m）  100m风速（100m/s）  100m风向（°) 出力(MW)  装机容量(MW)  \
# 0  286.0695         0.0  0.000008          9.0820    27.5093  17.26        48
# 1  285.8647         0.0  0.000008          9.1374    24.7151  16.78        48
# 2  285.6935         0.0  0.000008          9.1856    22.7445  16.25        48
# 3  285.5512         0.0  0.000008          9.2158    21.4374  15.37        48
# 4  285.4330         0.0  0.000008          9.2237    20.6417  15.64        48
#
#    站点编号_le                time  day  weekday  hour  month  minute  time_96  \
# 0        1 2022-01-03 00:00:00    3        0     0      1       0      1.0
# 1        1 2022-01-03 00:15:00    3        0     0      1      15      2.0
# 2        1 2022-01-03 00:30:00    3        0     0      1      30      3.0
# 3        1 2022-01-03 00:45:00    3        0     0      1      45      4.0
# 4        1 2022-01-03 01:00:00    3        0     1      1       0      5.0
#
#    100m风速（100m/s）_mean  10米风速（10m/s）_mean
# 0             9.394440           7.586195
# 1             9.394440           7.586195
# 2             9.394440           7.586195
# 3             9.394440           7.586195
# 4             9.666832           7.818008
# gap feature
# 231840
# 231840
#   站点编号             时间       气压(Pa）  相对湿度（%）        云量  10米风速（10m/s）  10米风向（°)  \
# 0   f1  2022-1-3 0:00  102249.6094  74.8513  0.007812        7.7041   26.5195
# 1   f1  2022-1-3 0:15  102252.0355  74.7530  0.000924        7.7710   23.5766
# 2   f1  2022-1-3 0:30  102248.5900  74.4995  0.003009        7.8272   21.5451
# 3   f1  2022-1-3 0:45  102240.4725  74.1432  0.011402        7.8637   20.2394
# 4   f1  2022-1-3 1:00  102228.8828  73.7366  0.023438        7.8781   19.4870
#
#       温度（K）  辐照强度（J/m2）     降水（m）  100m风速（100m/s）  100m风向（°)    出力(MW)  \
# 0  286.0695         0.0  0.000008          9.0820    27.5093  0.359583
# 1  285.8647         0.0  0.000008          9.1374    24.7151  0.349583
# 2  285.6935         0.0  0.000008          9.1856    22.7445  0.338542
# 3  285.5512         0.0  0.000008          9.2158    21.4374  0.320208
# 4  285.4330         0.0  0.000008          9.2237    20.6417  0.325833
#
#    装机容量(MW)  站点编号_le                time  day  weekday  hour  month  minute  \
# 0        48        1 2022-01-03 00:00:00    3        0     0      1       0
# 1        48        1 2022-01-03 00:15:00    3        0     0      1      15
# 2        48        1 2022-01-03 00:30:00    3        0     0      1      30
# 3        48        1 2022-01-03 00:45:00    3        0     0      1      45
# 4        48        1 2022-01-03 01:00:00    3        0     1      1       0
#
#    time_96  100m风速（100m/s）_mean  10米风速（10m/s）_mean  10米风向（°)_sin  \
# 0      1.0             9.394440           7.586195      0.446502
# 1      2.0             9.394440           7.586195      0.399975
# 2      3.0             9.394440           7.586195      0.367233
# 3      4.0             9.394440           7.586195      0.345943
# 4      5.0             9.666832           7.818008      0.333593
#
#    10米风向（°)_cos  100m风向（°)_sin  100m风向（°)_cos  气压(Pa）_gap1  相对湿度（%）_gap1  \
# 0      0.894782       0.461893       0.886936 -102249.6094      -74.8513
# 1      0.916526       0.418106       0.908398      -2.4261        0.0983
# 2      0.930129       0.386622       0.922238       3.4455        0.2535
# 3      0.938255       0.365484       0.930817       8.1175        0.3563
# 4      0.942717       0.352523       0.935803      11.5897        0.4066
#
#     云量_gap1  10米风速（10m/s）_gap1  温度（K）_gap1  降水（m）_gap1  100m风速（100m/s）_gap1  \
# 0 -0.007812            -7.7041   -286.0695   -0.000008              -9.0820
# 1  0.006889            -0.0669      0.2048    0.000000              -0.0554
# 2 -0.002085            -0.0562      0.1712    0.000000              -0.0482
# 3 -0.008393            -0.0365      0.1423    0.000000              -0.0302
# 4 -0.012036            -0.0144      0.1182    0.000000              -0.0079
#
#    气压(Pa）_gap2  相对湿度（%）_gap2   云量_gap2  10米风速（10m/s）_gap2  温度（K）_gap2  \
# 0 -102249.6094      -74.8513 -0.007812            -7.7041   -286.0695
# 1 -102252.0355      -74.7530 -0.000924            -7.7710   -285.8647
# 2       1.0194        0.3518  0.004804            -0.1231      0.3760
# 3      11.5630        0.6098 -0.010478            -0.0927      0.3135
# 4      19.7072        0.7629 -0.020429            -0.0509      0.2605
#
#    降水（m）_gap2  100m风速（100m/s）_gap2  气压(Pa）_gap4  相对湿度（%）_gap4   云量_gap4  \
# 0   -0.000008              -9.0820 -102249.6094      -74.8513 -0.007812
# 1   -0.000008              -9.1374 -102252.0355      -74.7530 -0.000924
# 2    0.000000              -0.1036 -102248.5900      -74.4995 -0.003009
# 3    0.000000              -0.0784 -102240.4725      -74.1432 -0.011402
# 4    0.000000              -0.0381      20.7266        1.1147 -0.015626
#
#    10米风速（10m/s）_gap4  温度（K）_gap4  降水（m）_gap4  100m风速（100m/s）_gap4  \
# 0            -7.7041   -286.0695   -0.000008              -9.0820
# 1            -7.7710   -285.8647   -0.000008              -9.1374
# 2            -7.8272   -285.6935   -0.000008              -9.1856
# 3            -7.8637   -285.5512   -0.000008              -9.2158
# 4            -0.1740      0.6365    0.000000              -0.1417
#
#    气压(Pa）_gap8  相对湿度（%）_gap8   云量_gap8  10米风速（10m/s）_gap8  温度（K）_gap8  \
# 0 -102249.6094      -74.8513 -0.007812            -7.7041   -286.0695
# 1 -102252.0355      -74.7530 -0.000924            -7.7710   -285.8647
# 2 -102248.5900      -74.4995 -0.003009            -7.8272   -285.6935
# 3 -102240.4725      -74.1432 -0.011402            -7.8637   -285.5512
# 4 -102228.8828      -73.7366 -0.023438            -7.8781   -285.4330
#
#    降水（m）_gap8  100m风速（100m/s）_gap8  气压(Pa）_gap16  相对湿度（%）_gap16  云量_gap16  \
# 0   -0.000008              -9.0820  -102249.6094       -74.8513 -0.007812
# 1   -0.000008              -9.1374  -102252.0355       -74.7530 -0.000924
# 2   -0.000008              -9.1856  -102248.5900       -74.4995 -0.003009
# 3   -0.000008              -9.2158  -102240.4725       -74.1432 -0.011402
# 4   -0.000008              -9.2237  -102228.8828       -73.7366 -0.023438
#
#    10米风速（10m/s）_gap16  温度（K）_gap16  降水（m）_gap16  100m风速（100m/s）_gap16  \
# 0             -7.7041    -286.0695    -0.000008               -9.0820
# 1             -7.7710    -285.8647    -0.000008               -9.1374
# 2             -7.8272    -285.6935    -0.000008               -9.1856
# 3             -7.8637    -285.5512    -0.000008               -9.2158
# 4             -7.8781    -285.4330    -0.000008               -9.2237
#
#    气压(Pa）_gap32  相对湿度（%）_gap32  云量_gap32  10米风速（10m/s）_gap32  温度（K）_gap32  \
# 0  -102249.6094       -74.8513 -0.007812             -7.7041    -286.0695
# 1  -102252.0355       -74.7530 -0.000924             -7.7710    -285.8647
# 2  -102248.5900       -74.4995 -0.003009             -7.8272    -285.6935
# 3  -102240.4725       -74.1432 -0.011402             -7.8637    -285.5512
# 4  -102228.8828       -73.7366 -0.023438             -7.8781    -285.4330
#
#    降水（m）_gap32  100m风速（100m/s）_gap32  气压(Pa）_gap48  相对湿度（%）_gap48  云量_gap48  \
# 0    -0.000008               -9.0820  -102249.6094       -74.8513 -0.007812
# 1    -0.000008               -9.1374  -102252.0355       -74.7530 -0.000924
# 2    -0.000008               -9.1856  -102248.5900       -74.4995 -0.003009
# 3    -0.000008               -9.2158  -102240.4725       -74.1432 -0.011402
# 4    -0.000008               -9.2237  -102228.8828       -73.7366 -0.023438
#
#    10米风速（10m/s）_gap48  温度（K）_gap48  降水（m）_gap48  100m风速（100m/s）_gap48  \
# 0             -7.7041    -286.0695    -0.000008               -9.0820
# 1             -7.7710    -285.8647    -0.000008               -9.1374
# 2             -7.8272    -285.6935    -0.000008               -9.1856
# 3             -7.8637    -285.5512    -0.000008               -9.2158
# 4             -7.8781    -285.4330    -0.000008               -9.2237
#
#    气压(Pa）_gap96  相对湿度（%）_gap96  云量_gap96  10米风速（10m/s）_gap96  温度（K）_gap96  \
# 0  -102249.6094       -74.8513 -0.007812             -7.7041    -286.0695
# 1  -102252.0355       -74.7530 -0.000924             -7.7710    -285.8647
# 2  -102248.5900       -74.4995 -0.003009             -7.8272    -285.6935
# 3  -102240.4725       -74.1432 -0.011402             -7.8637    -285.5512
# 4  -102228.8828       -73.7366 -0.023438             -7.8781    -285.4330
#
#    降水（m）_gap96  100m风速（100m/s）_gap96  气压(Pa）_gap192  相对湿度（%）_gap192  \
# 0    -0.000008               -9.0820   -102249.6094        -74.8513
# 1    -0.000008               -9.1374   -102252.0355        -74.7530
# 2    -0.000008               -9.1856   -102248.5900        -74.4995
# 3    -0.000008               -9.2158   -102240.4725        -74.1432
# 4    -0.000008               -9.2237   -102228.8828        -73.7366
#
#    云量_gap192  10米风速（10m/s）_gap192  温度（K）_gap192  降水（m）_gap192  \
# 0  -0.007812              -7.7041     -286.0695     -0.000008
# 1  -0.000924              -7.7710     -285.8647     -0.000008
# 2  -0.003009              -7.8272     -285.6935     -0.000008
# 3  -0.011402              -7.8637     -285.5512     -0.000008
# 4  -0.023438              -7.8781     -285.4330     -0.000008
#
#    100m风速（100m/s）_gap192  气压(Pa）_gap288  相对湿度（%）_gap288  云量_gap288  \
# 0                -9.0820   -102249.6094        -74.8513  -0.007812
# 1                -9.1374   -102252.0355        -74.7530  -0.000924
# 2                -9.1856   -102248.5900        -74.4995  -0.003009
# 3                -9.2158   -102240.4725        -74.1432  -0.011402
# 4                -9.2237   -102228.8828        -73.7366  -0.023438
#
#    10米风速（10m/s）_gap288  温度（K）_gap288  降水（m）_gap288  100m风速（100m/s）_gap288
# 0              -7.7041     -286.0695     -0.000008                -9.0820
# 1              -7.7710     -285.8647     -0.000008                -9.1374
# 2              -7.8272     -285.6935     -0.000008                -9.1856
# 3              -7.8637     -285.5512     -0.000008                -9.2158
# 4              -7.8781     -285.4330     -0.000008                -9.2237
# ['气压(Pa）', '相对湿度（%）', '云量', '10米风速（10m/s）', '10米风向（°)', '温度（K）', '辐照强度（J/m2）', '降水（m）', '100m风速（100m/s）', '100m风向（°)', '装机容量(MW)', '站点编号_le', 'day', 'weekday', 'hour', 'month', 'time_96', '100m风速（100m/s）_mean', '10米风速（10m/s）_mean', '10米风向（°)_sin', '10米风向（°)_cos', '100m风向（°)_sin', '100m风向（°)_cos', '气压(Pa）_gap1', '相对湿度（%）_gap1', '云量_gap1', '10米风速（10m/s）_gap1', '温度（K）_gap1', '降水（m）_gap1', '100m风速（100m/s）_gap1', '气压(Pa）_gap2', '相对湿度（%）_gap2', '云量_gap2', '10米风速（10m/s）_gap2', '温度（K）_gap2', '降水（m）_gap2', '100m风速（100m/s）_gap2', '气压(Pa）_gap4', '相对湿度（%）_gap4', '云量_gap4', '10米风速（10m/s）_gap4', '温度（K）_gap4', '降水（m）_gap4', '100m风速（100m/s）_gap4', '气压(Pa）_gap8', '相对湿度（%）_gap8', '云量_gap8', '10米风速（10m/s）_gap8', '温度（K）_gap8', '降水（m）_gap8', '100m风速（100m/s）_gap8', '气压(Pa）_gap16', '相对湿度（%）_gap16', '云量_gap16', '10米风速（10m/s）_gap16', '温度（K）_gap16', '降水（m）_gap16', '100m风速（100m/s）_gap16', '气压(Pa）_gap32', '相对湿度（%）_gap32', '云量_gap32', '10米风速（10m/s）_gap32', '温度（K）_gap32', '降水（m）_gap32', '100m风速（100m/s）_gap32', '气压(Pa）_gap48', '相对湿度（%）_gap48', '云量_gap48', '10米风速（10m/s）_gap48', '温度（K）_gap48', '降水（m）_gap48', '100m风速（100m/s）_gap48', '气压(Pa）_gap96', '相对湿度（%）_gap96', '云量_gap96', '10米风速（10m/s）_gap96', '温度（K）_gap96', '降水（m）_gap96', '100m风速（100m/s）_gap96', '气压(Pa）_gap192', '相对湿度（%）_gap192', '云量_gap192', '10米风速（10m/s）_gap192', '温度（K）_gap192', '降水（m）_gap192', '100m风速（100m/s）_gap192', '气压(Pa）_gap288', '相对湿度（%）_gap288', '云量_gap288', '10米风速（10m/s）_gap288', '温度（K）_gap288', '降水（m）_gap288', '100m风速（100m/s）_gap288']
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.026503 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 22112
# [LightGBM] [Info] Number of data points in the train set: 189120, number of used features: 93
# [LightGBM] [Info] Start training from score 0.318277
# Training until validation scores don't improve for 200 rounds
# [100]	training's l2: 0.0150449	valid_1's l2: 0.0242672
# [200]	training's l2: 0.011412	valid_1's l2: 0.0231045
# [300]	training's l2: 0.00962392	valid_1's l2: 0.0229137
# [400]	training's l2: 0.00844828	valid_1's l2: 0.0228416
# [500]	training's l2: 0.00753959	valid_1's l2: 0.0228293
# [600]	training's l2: 0.00676134	valid_1's l2: 0.0228076
# [700]	training's l2: 0.00616069	valid_1's l2: 0.0228127
# [800]	training's l2: 0.00559308	valid_1's l2: 0.0228073
# Early stopping, best iteration is:
# [640]	training's l2: 0.00650547	valid_1's l2: 0.0227885
# score... 0.04805 rmse...19.81254
# feature importance of lightgbm:
#                      name     importance
# 8          100m风速（100m/s）  148923.688513
# 3            10米风速（10m/s）   21166.826304
# 11                站点编号_le    4988.566603
# 10               装机容量(MW)    4374.500635
# 9               100m风向（°)    4031.204072
# 17    100m风速（100m/s）_mean    3005.759694
# 22          100m风向（°)_cos    2862.547145
# 0                  气压(Pa）    1966.182150
# 5                   温度（K）    1760.190948
# 4                10米风向（°)    1736.780890
# 12                    day    1648.967256
# 84           降水（m）_gap192    1553.711726
# 7                   降水（m）    1511.912179
# 92  100m风速（100m/s）_gap288    1507.124842
# 91           降水（m）_gap288    1433.407588
# 72           气压(Pa）_gap96    1414.003095
# 57   100m风速（100m/s）_gap16    1406.736599
# 86          气压(Pa）_gap288    1281.170062
# 20           10米风向（°)_cos    1256.161108
# 15                  month    1157.360683
# 19           10米风向（°)_sin    1125.328731
# 77            降水（m）_gap96    1125.305679
# 82    10米风速（10m/s）_gap192    1102.051469
# 21          100m风向（°)_sin    1090.902385
# 89    10米风速（10m/s）_gap288     998.584319
# 76            温度（K）_gap96     993.878579
# 83           温度（K）_gap192     894.541534
# 18      10米风速（10m/s）_mean     880.069200
# 90           温度（K）_gap288     878.172788
# 79          气压(Pa）_gap192     782.526576
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034417 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 22112
# [LightGBM] [Info] Number of data points in the train set: 231840, number of used features: 93
# [LightGBM] [Info] Start training from score 0.314706

# %%
# from lunarcalendar import LunarCalendar  
from lunarcalendar import Converter, Solar, Lunar


# 定义一个函数来转换 datetime 到农历日期  
def datetime_to_lunar(time):  
#     lunar_date = LunarCalendar.fromSolarDate(dt.year, dt.month, dt.day)  
    lunar_date = Converter.Solar2Lunar(time)  
    return lunar_date.month, lunar_date.day
  
# 应用函数到 DataFrame 的 'date' 列  
df['month_lunar'], df['day_lunar'] = df['time'].apply(datetime_to_lunar)  
print(df)
# df['month_lunar'] = df['lunar_date'].month
# df['day_lunar'] = df['lunar_date'].day


solar = Solar(2018, 1, 1)
print(solar)
lunar = Converter.Solar2Lunar(solar)
print(lunar)
solar = Converter.Lunar2Solar(lunar)
print(solar)
print(solar.to_date(), type(solar.to_date()))


# 示例 DataFrame  
df = pd.DataFrame({  
    'date': ['2023-01-01', '2023-02-11', '2023-03-15']  
})  
  
# 将字符串转换为 datetime 对象  
df['date'] = pd.to_datetime(df['date'])  
  
# 定义一个函数来转换 datetime 到农历日期  
def datetime_to_lunar(dt):  
#     lunar_date = LunarCalendar.fromSolarDate(dt.year, dt.month, dt.day)  
    lunar_date = Converter.Solar2Lunar(dt)  
    return f"{lunar_date.year}年{lunar_date.month}月{lunar_date.day}日"  
  
# 应用函数到 DataFrame 的 'date' 列  
df['lunar_date'] = df['date'].apply(datetime_to_lunar)  
  
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Softwares\miniconda\lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[124], line 12
#       9     return lunar_date.month, lunar_date.day
#      11 # 应用函数到 DataFrame 的 'date' 列
# ---> 12 df['month_lunar'], df['day_lunar'] = df['time'].apply(datetime_to_lunar)
#      13 print(df)
#      14 # df['month_lunar'] = df['lunar_date'].month
#      15 # df['day_lunar'] = df['lunar_date'].day
#
# File D:\Softwares\miniconda\lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File D:\Softwares\miniconda\lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'time'

# %%
from matplotlib import rcParams
from statsmodels.graphics.tsaplots import plot_acf

LABEL = '出力(MW)'
df.loc[df[LABEL]=='<NULL>', LABEL] = None
df.bfill(inplace=True)
df[LABEL] = df[LABEL].astype('float32')

rcParams['figure.figsize'] = 14, 4
fig = plot_acf(df['100m风速（100m/s）'], lags=300)

plt.title('Autocorrelation of Degrees Celcius')
plt.ylabel('Correlation')
plt.xlabel('Lag at k')
fig.show()

# %%
df['weekday'] = df['time'].dt.weekday
df['day'] = df['time'].dt.day
print(df[0:5])
# print(df.groupby(['站点编号','weekday']).describe())
# fs_mean = df.groupby(['站点编号','weekday']).agg({'100m风速（100m/s）':'mean'})
# print(fs_mean)
# df['100m风速（100m/s）'+'_mean'] = df['100m风速（100m/s）'].groupby(df['站点编号','weekday']).mean()
# df['100m风速（100m/s）'+'_mean'] = df['100m风速（100m/s）'].groupby(df['站点编号']).mean()
# print(df[1:5])
df2 = df
print(len(df))
fs100_mean = df['100m风速（100m/s）'].groupby([df['站点编号'],df['weekday'],df['hour']]).mean()
fs10_mean = df['10米风速（10m/s）'].groupby([df['站点编号'],df['weekday'],df['hour']]).mean()
# print(fs100_mean)
# print(fs10_mean)

merged_df = pd.merge(df, fs100_mean, on=['站点编号','weekday', 'hour'])
merged_df = pd.merge(merged_df, fs10_mean, on=['站点编号','weekday', 'hour'])
print(merged_df[0:5])
merged_df = merged_df.assign(m100fs_mean=merged_df['100m风速（100m/s）_y'],m10fs_mean=merged_df['10米风速（10m/s）_y'])
merged_df = merged_df.drop(['100m风速（100m/s）_y', '10米风速（10m/s）_y'], axis=1)
print(merged_df[0:5])
merged_df = merged_df.sort_values(by=['站点编号','time'],ascending=[True, True])
merged_df = merged_df.reset_index(drop=True)
print(merged_df[0:5])
# for key, value in fs_mean:
#     print(key)
#     print(value)
#     print("")
# Out:
#   站点编号             时间       气压(Pa）  相对湿度（%）        云量  10米风速（10m/s）_x  \
# 0   f1  2022-1-3 0:00  102249.6094  74.8513  0.007812          7.7041
# 1   f1  2022-1-3 0:15  102252.0355  74.7530  0.000924          7.7710
# 2   f1  2022-1-3 0:30  102248.5900  74.4995  0.003009          7.8272
# 3   f1  2022-1-3 0:45  102240.4725  74.1432  0.011402          7.8637
# 4   f1  2022-1-3 1:00  102228.8828  73.7366  0.023438          7.8781
#
#    10米风向（°)     温度（K）  辐照强度（J/m2）     降水（m）  100m风速（100m/s）_x  100m风向（°)  \
# 0   26.5195  286.0695         0.0  0.000008            9.0820    27.5093
# 1   23.5766  285.8647         0.0  0.000008            9.1374    24.7151
# 2   21.5451  285.6935         0.0  0.000008            9.1856    22.7445
# 3   20.2394  285.5512         0.0  0.000008            9.2158    21.4374
# 4   19.4870  285.4330         0.0  0.000008            9.2237    20.6417
#
#   出力(MW)  装机容量(MW)  站点编号_le                time  day  weekday  hour  month  \
# 0  17.26        48        1 2022-01-03 00:00:00    3        0     0      1
# 1  16.78        48        1 2022-01-03 00:15:00    3        0     0      1
# 2  16.25        48        1 2022-01-03 00:30:00    3        0     0      1
# 3  15.37        48        1 2022-01-03 00:45:00    3        0     0      1
# 4  15.64        48        1 2022-01-03 01:00:00    3        0     1      1
#
#    minute  hour_sin  hour_cos  time_96  m100fs_mean  m10fs_mean  10米风向（°)_sin  \
# 0       0  0.000000  1.000000      1.0     8.444211    6.680610      0.446502
# 1      15  0.000000  1.000000      2.0     8.444211    6.680610      0.399975
# 2      30  0.000000  1.000000      3.0     8.444211    6.680610      0.367233
# 3      45  0.000000  1.000000      4.0     8.444211    6.680610      0.345943
# 4       0  0.269797  0.962917      5.0     8.366766    6.616443      0.333593
#
#    10米风向（°)_cos  100m风向（°)_sin  100m风向（°)_cos  气压(Pa）_gap1  相对湿度（%）_gap1  \
# 0      0.894782       0.461893       0.886936          NaN           NaN
# 1      0.916526       0.418106       0.908398      -2.4261        0.0983
# 2      0.930129       0.386622       0.922238       3.4455        0.2535
# 3      0.938255       0.365484       0.930817       8.1175        0.3563
# 4      0.942717       0.352523       0.935803      11.5897        0.4066
#
#     云量_gap1
# 0       NaN
# 1  0.006889
# 2 -0.002085
# 3 -0.008393
# 4 -0.012036
# 276000
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Softwares\miniconda\lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '100m风速（100m/s）'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 12
#      10 df2 = df
#      11 print(len(df))
# ---> 12 fs100_mean = df['100m风速（100m/s）'].groupby([df['站点编号'],df['weekday'],df['hour']]).mean()
#      13 fs10_mean = df['10米风速（10m/s）'].groupby([df['站点编号'],df['weekday'],df['hour']]).mean()
#      14 # print(fs100_mean)
#      15 # print(fs10_mean)
#
# File D:\Softwares\miniconda\lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File D:\Softwares\miniconda\lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: '100m风速（100m/s）'

# %%
df_res1 = pd.read_csv('ans/lgb_base_0.04826.csv', encoding='utf-8')
df_res2 = pd.read_csv('ans/bilstm-UTF-8.csv', encoding='utf-8')
print(df_res1, df_res2)
df_res1['出力(MW)'] = (df_res1['出力(MW)']+df_res2['出力(MW)'])/2
df_res1[['站点编号','时间','出力(MW)']].to_csv('ans/lgb_bilstm.csv', index=False)
# Out:
#       站点编号               时间    出力(MW)
# 0       f1    2023-5-1 0:00  5.668540
# 1       f1    2023-5-1 0:15  5.734170
# 2       f1    2023-5-1 0:30  6.168911
# 3       f1    2023-5-1 0:45  6.114414
# 4       f1    2023-5-1 1:00  6.774835
# ...    ...              ...       ...
# 44155   f5  2023-7-31 22:45  3.485310
# 44156   f5  2023-7-31 23:00  3.850666
# 44157   f5  2023-7-31 23:15  3.591922
# 44158   f5  2023-7-31 23:30  3.709665
# 44159   f5  2023-7-31 23:45  3.578127
#
# [44160 rows x 3 columns]       站点编号               时间    出力(MW)
# 0       f1    2023-5-1 0:00  5.668540
# 1       f1    2023-5-1 0:15  5.734170
# 2       f1    2023-5-1 0:30  6.168911
# 3       f1    2023-5-1 0:45  6.114414
# 4       f1    2023-5-1 1:00  6.774835
# ...    ...              ...       ...
# 44155   f5  2023-7-31 22:45  3.485310
# 44156   f5  2023-7-31 23:00  3.850666
# 44157   f5  2023-7-31 23:15  3.591922
# 44158   f5  2023-7-31 23:30  3.709665
# 44159   f5  2023-7-31 23:45  3.578127
#
# [44160 rows x 3 columns]

# %%
params_cb['use_best_model'] = False
params_cb['iterations'] = model_cat.get_best_iteration()
model_cat = cb.CatBoostRegressor(**params_cb)
model_cat.fit(df_train[feats], df_train[LABEL], verbose=True, plot=True)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))

# %%
pred_y_cat = model_cat.predict(df_test[feats])
pred_y_fusion = (pred_y+pred_y_cat)/2

# df_test[LABEL] = pred_y*df_test['装机容量(MW)']
df_test[LABEL] = pred_y_fusion*df_test['装机容量(MW)']

# df_test[['站点编号','时间','出力(MW)']].to_csv('ans/lgb_base_%.5f.csv'%score, index=False)
df_test[['站点编号','时间','出力(MW)']].to_csv('ans/lgb_base_%.5f.csv'%score_fusion, index=False)

# %%
print(model_cat.get_feature_importance(prettified=True)[:30])
# Out:
#               Feature Id  Importances
# 0         100m风速（100m/s）    14.881744
# 1     100m风速（100m/s）_cub    11.987800
# 2     100m风速（100m/s）_squ    11.588024
# 3                站点编号_le     8.912412
# 4               装机容量(MW)     4.321363
# 5           10米风速（10m/s）     3.857386
# 6           10米风向（°)_cos     3.067667
# 7          100m风向（°)_cos     3.002037
# 8       10米风速（10m/s）_cub     2.982832
# 9       10米风速（10m/s）_squ     2.605273
# 10                气压(Pa）     1.679698
# 11                 温度（K）     1.675823
# 12                 降水（m）     1.496285
# 13          降水（m）_gap192     1.460827
# 14                 month     1.438892
# 15          10米风向（°)_sin     1.332104
# 16         100m风向（°)_sin     1.317056
# 17  100m风速（100m/s）_gap16     1.309311
# 18          气压(Pa）_gap96     1.254580
# 19          温度（K）_gap192     1.017003
# 20         气压(Pa）_gap288     0.929068
# 21          降水（m）_gap288     0.911467
# 22          温度（K）_gap288     0.834891
# 23       100m风向（°)_gap48     0.753767
# 24           降水（m）_gap96     0.734749
# 25              10米风向（°)     0.653028
# 26   100m风速（100m/s）_gap8     0.624906
# 27             100m风向（°)     0.586772
# 28         气压(Pa）_gap192     0.575825
# 29           温度（K）_gap96     0.560482

# %%
print(feats_importance.sort_values('importance', ascending=False)[:30])
# Out:
#                      name    importance
# 8          100m风速（100m/s）  84123.268067
# 19     100m风速（100m/s）_squ  15567.801610
# 3            10米风速（10m/s）   8466.845898
# 11                站点编号_le   3452.650916
# 10               装机容量(MW)   2068.116154
# 24          100m风向（°)_cos   1737.428582
# 22           10米风向（°)_cos    941.491998
# 9               100m风向（°)    907.497422
# 73   100m风速（100m/s）_gap16    828.354671
# 7                   降水（m）    761.623503
# 95           气压(Pa）_gap96    718.305258
# 122          降水（m）_gap288    689.371818
# 5                   温度（K）    658.576792
# 112          降水（m）_gap192    637.863407
# 0                  气压(Pa）    622.455932
# 23          100m风向（°)_sin    611.953618
# 4                10米风向（°)    518.474082
# 102           降水（m）_gap96    500.641103
# 115         气压(Pa）_gap288    495.095053
# 18       10米风速（10m/s）_cub    494.893824
# 94        100m风向（°)_gap48    453.384743
# 21           10米风向（°)_sin    444.333762
# 120          温度（K）_gap288    415.548699
# 110          温度（K）_gap192    401.435997
# 13                  month    396.535854
# 124      100m风向（°)_gap288    348.896008
# 85           气压(Pa）_gap48    328.251038
# 100           温度（K）_gap96    325.149570
# 63    100m风速（100m/s）_gap8    321.978201
# 17       10米风速（10m/s）_squ    312.879945

# %%
print(model_cat.get_feature_importance(prettified=True)[-30:])
# Out:
#               Feature Id  Importances
# 95        10米风向（°)_gap16     0.013942
# 96       辐照强度（J/m2）_gap1     0.012317
# 97           气压(Pa）_gap4     0.011158
# 98       辐照强度（J/m2）_gap2     0.009906
# 99              云量_gap48     0.007937
# 100      辐照强度（J/m2）_gap8     0.005413
# 101         相对湿度（%）_gap4     0.005092
# 102          气压(Pa）_gap1     0.000000
# 103         相对湿度（%）_gap1     0.000000
# 104              云量_gap1     0.000000
# 105        10米风向（°)_gap1     0.000000
# 106           降水（m）_gap1     0.000000
# 107       100m风向（°)_gap1     0.000000
# 108          气压(Pa）_gap2     0.000000
# 109         相对湿度（%）_gap2     0.000000
# 110              云量_gap2     0.000000
# 111    10米风速（10m/s）_gap2     0.000000
# 112        10米风向（°)_gap2     0.000000
# 113           降水（m）_gap2     0.000000
# 114  100m风速（100m/s）_gap2     0.000000
# 115       100m风向（°)_gap2     0.000000
# 116              云量_gap4     0.000000
# 117        10米风向（°)_gap4     0.000000
# 118           降水（m）_gap4     0.000000
# 119       100m风向（°)_gap4     0.000000
# 120         相对湿度（%）_gap8     0.000000
# 121              云量_gap8     0.000000
# 122           降水（m）_gap8     0.000000
# 123        相对湿度（%）_gap16     0.000000
# 124             云量_gap32     0.000000

# %%
print(feats_importance.sort_values('importance', ascending=False)[-30:])
# Out:
#                    name  importance
# 20   100m风速（100m/s）_cub   22.688656
# 45          气压(Pa）_gap4   21.681755
# 30           温度（K）_gap1   21.436572
# 56         相对湿度（%）_gap8   20.535656
# 50           温度（K）_gap4   19.829179
# 31      辐照强度（J/m2）_gap1   17.796809
# 28    10米风速（10m/s）_gap1   17.272564
# 57              云量_gap8   12.151867
# 41      辐照强度（J/m2）_gap2   10.983070
# 49        10米风向（°)_gap4   10.702658
# 29        10米风向（°)_gap1    9.498237
# 52           降水（m）_gap4    8.967236
# 32           降水（m）_gap1    8.511863
# 46         相对湿度（%）_gap4    8.236831
# 40           温度（K）_gap2    7.870480
# 51      辐照强度（J/m2）_gap4    7.528484
# 25          气压(Pa）_gap1    7.503066
# 26         相对湿度（%）_gap1    7.456437
# 43  100m风速（100m/s）_gap2    6.246414
# 34       100m风向（°)_gap1    5.884441
# 42           降水（m）_gap2    5.145167
# 35          气压(Pa）_gap2    5.094187
# 36         相对湿度（%）_gap2    4.936386
# 54       100m风向（°)_gap4    3.794752
# 44       100m风向（°)_gap2    3.730027
# 38    10米风速（10m/s）_gap2    3.354677
# 37              云量_gap2    2.501483
# 47              云量_gap4    2.043427
# 27              云量_gap1    1.637177
# 39        10米风向（°)_gap2    0.931454

# %%
print(df.head())
# Out:
#   站点编号             时间       气压(Pa）  相对湿度（%）        云量  10米风速（10m/s）  10米风向（°)  \
# 0   f1  2022-1-3 0:00  102249.6094  74.8513  0.007812        7.7041   26.5195
# 1   f1  2022-1-3 0:15  102252.0355  74.7530  0.000924        7.7710   23.5766
# 2   f1  2022-1-3 0:30  102248.5900  74.4995  0.003009        7.8272   21.5451
# 3   f1  2022-1-3 0:45  102240.4725  74.1432  0.011402        7.8637   20.2394
# 4   f1  2022-1-3 1:00  102228.8828  73.7366  0.023438        7.8781   19.4870
#
#       温度（K）  辐照强度（J/m2）     降水（m）  100m风速（100m/s）  100m风向（°) 出力(MW)  装机容量(MW)  \
# 0  286.0695         0.0  0.000008          9.0820    27.5093  17.26        48
# 1  285.8647         0.0  0.000008          9.1374    24.7151  16.78        48
# 2  285.6935         0.0  0.000008          9.1856    22.7445  16.25        48
# 3  285.5512         0.0  0.000008          9.2158    21.4374  15.37        48
# 4  285.4330         0.0  0.000008          9.2237    20.6417  15.64        48
#
#    站点编号_le                time  hour  month  minute  hour_sin  hour_cos  \
# 0        1 2022-01-03 00:00:00     0      1       0  0.000000  1.000000
# 1        1 2022-01-03 00:15:00     0      1      15  0.000000  1.000000
# 2        1 2022-01-03 00:30:00     0      1      30  0.000000  1.000000
# 3        1 2022-01-03 00:45:00     0      1      45  0.000000  1.000000
# 4        1 2022-01-03 01:00:00     1      1       0  0.269797  0.962917
#
#    minute_sin  minute_cos  time_96  气压(Pa）_gap1  相对湿度（%）_gap1   云量_gap1  \
# 0    0.000000    1.000000      1.0          NaN           NaN       NaN
# 1    0.999646   -0.026621      2.0      -2.4261        0.0983  0.006889
# 2   -0.053222   -0.998583      3.0       3.4455        0.2535 -0.002085
# 3   -0.996812    0.079786      4.0       8.1175        0.3563 -0.008393
# 4    0.000000    1.000000      5.0      11.5897        0.4066 -0.012036
#
#    10米风速（10m/s）_gap1  10米风向（°)_gap1  温度（K）_gap1  辐照强度（J/m2）_gap1  降水（m）_gap1  \
# 0                NaN            NaN         NaN              NaN         NaN
# 1            -0.0669         2.9429      0.2048              0.0         0.0
# 2            -0.0562         2.0315      0.1712              0.0         0.0
# 3            -0.0365         1.3057      0.1423              0.0         0.0
# 4            -0.0144         0.7524      0.1182              0.0         0.0
#
#    100m风速（100m/s）_gap1  100m风向（°)_gap1  气压(Pa）_gap2  相对湿度（%）_gap2   云量_gap2  \
# 0                  NaN             NaN          NaN           NaN       NaN
# 1              -0.0554          2.7942          NaN           NaN       NaN
# 2              -0.0482          1.9706       1.0194        0.3518  0.004804
# 3              -0.0302          1.3071      11.5630        0.6098 -0.010478
# 4              -0.0079          0.7957      19.7072        0.7629 -0.020429
#
#    10米风速（10m/s）_gap2  10米风向（°)_gap2  温度（K）_gap2  辐照强度（J/m2）_gap2  降水（m）_gap2  \
# 0                NaN            NaN         NaN              NaN         NaN
# 1                NaN            NaN         NaN              NaN         NaN
# 2            -0.1231         4.9744      0.3760              0.0         0.0
# 3            -0.0927         3.3372      0.3135              0.0         0.0
# 4            -0.0509         2.0581      0.2605              0.0         0.0
#
#    100m风速（100m/s）_gap2  100m风向（°)_gap2  气压(Pa）_gap4  相对湿度（%）_gap4   云量_gap4  \
# 0                  NaN             NaN          NaN           NaN       NaN
# 1                  NaN             NaN          NaN           NaN       NaN
# 2              -0.1036          4.7648          NaN           NaN       NaN
# 3              -0.0784          3.2777          NaN           NaN       NaN
# 4              -0.0381          2.1028      20.7266        1.1147 -0.015626
#
#    10米风速（10m/s）_gap4  10米风向（°)_gap4  温度（K）_gap4  辐照强度（J/m2）_gap4  降水（m）_gap4  \
# 0                NaN            NaN         NaN              NaN         NaN
# 1                NaN            NaN         NaN              NaN         NaN
# 2                NaN            NaN         NaN              NaN         NaN
# 3                NaN            NaN         NaN              NaN         NaN
# 4             -0.174         7.0325      0.6365              0.0         0.0
#
#    100m风速（100m/s）_gap4  100m风向（°)_gap4  气压(Pa）_gap8  相对湿度（%）_gap8  云量_gap8  \
# 0                  NaN             NaN          NaN           NaN      NaN
# 1                  NaN             NaN          NaN           NaN      NaN
# 2                  NaN             NaN          NaN           NaN      NaN
# 3                  NaN             NaN          NaN           NaN      NaN
# 4              -0.1417          6.8676          NaN           NaN      NaN
#
#    10米风速（10m/s）_gap8  10米风向（°)_gap8  温度（K）_gap8  辐照强度（J/m2）_gap8  降水（m）_gap8  \
# 0                NaN            NaN         NaN              NaN         NaN
# 1                NaN            NaN         NaN              NaN         NaN
# 2                NaN            NaN         NaN              NaN         NaN
# 3                NaN            NaN         NaN              NaN         NaN
# 4                NaN            NaN         NaN              NaN         NaN
#
#    100m风速（100m/s）_gap8  100m风向（°)_gap8  气压(Pa）_gap16  相对湿度（%）_gap16  云量_gap16  \
# 0                  NaN             NaN           NaN            NaN       NaN
# 1                  NaN             NaN           NaN            NaN       NaN
# 2                  NaN             NaN           NaN            NaN       NaN
# 3                  NaN             NaN           NaN            NaN       NaN
# 4                  NaN             NaN           NaN            NaN       NaN
#
#    10米风速（10m/s）_gap16  10米风向（°)_gap16  温度（K）_gap16  辐照强度（J/m2）_gap16  \
# 0                 NaN             NaN          NaN               NaN
# 1                 NaN             NaN          NaN               NaN
# 2                 NaN             NaN          NaN               NaN
# 3                 NaN             NaN          NaN               NaN
# 4                 NaN             NaN          NaN               NaN
#
#    降水（m）_gap16  100m风速（100m/s）_gap16  100m风向（°)_gap16  气压(Pa）_gap32  \
# 0          NaN                   NaN              NaN           NaN
# 1          NaN                   NaN              NaN           NaN
# 2          NaN                   NaN              NaN           NaN
# 3          NaN                   NaN              NaN           NaN
# 4          NaN                   NaN              NaN           NaN
#
#    相对湿度（%）_gap32  云量_gap32  10米风速（10m/s）_gap32  10米风向（°)_gap32  温度（K）_gap32  \
# 0            NaN       NaN                 NaN             NaN          NaN
# 1            NaN       NaN                 NaN             NaN          NaN
# 2            NaN       NaN                 NaN             NaN          NaN
# 3            NaN       NaN                 NaN             NaN          NaN
# 4            NaN       NaN                 NaN             NaN          NaN
#
#    辐照强度（J/m2）_gap32  降水（m）_gap32  100m风速（100m/s）_gap32  100m风向（°)_gap32  \
# 0               NaN          NaN                   NaN              NaN
# 1               NaN          NaN                   NaN              NaN
# 2               NaN          NaN                   NaN              NaN
# 3               NaN          NaN                   NaN              NaN
# 4               NaN          NaN                   NaN              NaN
#
#    气压(Pa）_gap48  相对湿度（%）_gap48  云量_gap48  10米风速（10m/s）_gap48  10米风向（°)_gap48  \
# 0           NaN            NaN       NaN                 NaN             NaN
# 1           NaN            NaN       NaN                 NaN             NaN
# 2           NaN            NaN       NaN                 NaN             NaN
# 3           NaN            NaN       NaN                 NaN             NaN
# 4           NaN            NaN       NaN                 NaN             NaN
#
#    温度（K）_gap48  辐照强度（J/m2）_gap48  降水（m）_gap48  100m风速（100m/s）_gap48  \
# 0          NaN               NaN          NaN                   NaN
# 1          NaN               NaN          NaN                   NaN
# 2          NaN               NaN          NaN                   NaN
# 3          NaN               NaN          NaN                   NaN
# 4          NaN               NaN          NaN                   NaN
#
#    100m风向（°)_gap48  气压(Pa）_gap96  相对湿度（%）_gap96  云量_gap96  10米风速（10m/s）_gap96  \
# 0              NaN           NaN            NaN       NaN                 NaN
# 1              NaN           NaN            NaN       NaN                 NaN
# 2              NaN           NaN            NaN       NaN                 NaN
# 3              NaN           NaN            NaN       NaN                 NaN
# 4              NaN           NaN            NaN       NaN                 NaN
#
#    10米风向（°)_gap96  温度（K）_gap96  辐照强度（J/m2）_gap96  降水（m）_gap96  \
# 0             NaN          NaN               NaN          NaN
# 1             NaN          NaN               NaN          NaN
# 2             NaN          NaN               NaN          NaN
# 3             NaN          NaN               NaN          NaN
# 4             NaN          NaN               NaN          NaN
#
#    100m风速（100m/s）_gap96  100m风向（°)_gap96  气压(Pa）_gap192  相对湿度（%）_gap192  \
# 0                   NaN              NaN            NaN             NaN
# 1                   NaN              NaN            NaN             NaN
# 2                   NaN              NaN            NaN             NaN
# 3                   NaN              NaN            NaN             NaN
# 4                   NaN              NaN            NaN             NaN
#
#    云量_gap192  10米风速（10m/s）_gap192  10米风向（°)_gap192  温度（K）_gap192  \
# 0        NaN                  NaN              NaN           NaN
# 1        NaN                  NaN              NaN           NaN
# 2        NaN                  NaN              NaN           NaN
# 3        NaN                  NaN              NaN           NaN
# 4        NaN                  NaN              NaN           NaN
#
#    辐照强度（J/m2）_gap192  降水（m）_gap192  100m风速（100m/s）_gap192  100m风向（°)_gap192  \
# 0                NaN           NaN                    NaN               NaN
# 1                NaN           NaN                    NaN               NaN
# 2                NaN           NaN                    NaN               NaN
# 3                NaN           NaN                    NaN               NaN
# 4                NaN           NaN                    NaN               NaN
#
#    气压(Pa）_gap288  相对湿度（%）_gap288  云量_gap288  10米风速（10m/s）_gap288  \
# 0            NaN             NaN        NaN                  NaN
# 1            NaN             NaN        NaN                  NaN
# 2            NaN             NaN        NaN                  NaN
# 3            NaN             NaN        NaN                  NaN
# 4            NaN             NaN        NaN                  NaN
#
#    10米风向（°)_gap288  温度（K）_gap288  辐照强度（J/m2）_gap288  降水（m）_gap288  \
# 0              NaN           NaN                NaN           NaN
# 1              NaN           NaN                NaN           NaN
# 2              NaN           NaN                NaN           NaN
# 3              NaN           NaN                NaN           NaN
# 4              NaN           NaN                NaN           NaN
#
#    100m风速（100m/s）_gap288  100m风向（°)_gap288  order
# 0                    NaN               NaN      1
# 1                    NaN               NaN      2
# 2                    NaN               NaN      3
# 3                    NaN               NaN      4
# 4                    NaN               NaN      5
